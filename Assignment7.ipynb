# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyabhonagiri/AI-/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![AI 71.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![AI 72.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![AI 73.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![AI 74.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![AI 75.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![AI 76.jpeg](data:image/jpeg;base64,...)
