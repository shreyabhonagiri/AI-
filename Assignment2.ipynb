# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyabhonagiri/AI-/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2021-12-08 at 8.32.32 AM.jpeg](data:image/jpeg;base64,...)

# %%
x=2;
eta=0.001
eps=0.000001
delx=1
max_iter=10000
iter=0
def deriv(x):
  xderive=4*x*x*x+6*x
  return xderive

# %%
while abs(delx)>eps and iter<max_iter:
    prevx=x;
    delx=-eta*deriv(prevx)
    x=x+delx
    iter=iter+1
print("Value of local minimum occurs at ",round(x))
obj=x*x*x*x+3*x*x+10
print("Value of the Objective function is = ",round(obj))
# Out:
# Value of local minimum occurs at  0
# Value of the Objective function is =  10
